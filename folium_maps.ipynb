# %%
import geoplotlib
from geoplotlib.utils import read_csv, BoundingBox, DataAccessObject
import numpy
import csv
import pandas as pd

# %%
import folium
from folium.plugins import HeatMap
import pandas as pd

# Read the CSV file containing latitude, longitude, and postcode data
data = pd.read_csv('data_with_coordinates.csv')

# Create a map centered around the mean latitude and longitude coordinates
map_center = [data['latitude'].mean(), data['longitude'].mean()]
mymap = folium.Map(location=map_center, zoom_start=13)

# Convert latitude and longitude data to a list of points for heatmap
heat_data = data[['latitude', 'longitude']].values.tolist()

# Create a HeatMap layer
HeatMap(heat_data).add_to(mymap)

# Save the map to an HTML file
mymap.save('heatmap.html')

# Display the map
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium
import pandas as pd

# Read the CSV file containing latitude, longitude, and postcode data
data = pd.read_csv('data_with_coordinates.csv')

# Create a map centered around the mean latitude and longitude coordinates
map_center = [data['latitude'].mean(), data['longitude'].mean()]
mymap = folium.Map(location=map_center, zoom_start=14)

# Add markers for each postcode location
for index, row in data.iterrows():
    folium.Marker(location=[row['latitude'], row['longitude']],
                  popup=row['postcode'],
                  icon=folium.Icon(color='green')).add_to(mymap)  # Set marker color to purple

# Save the map to an HTML file
mymap.save('postcode_map.html')

# Display the map
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium
import pandas as pd

# Read the CSV file containing latitude, longitude, and postcode data
data = pd.read_csv('data_with_coordinates.csv')

# Create a map centered around the mean latitude and longitude coordinates
map_center = [data['latitude'].mean(), data['longitude'].mean()]
mymap = folium.Map(location=map_center, zoom_start=14)

# Add markers for each postcode location
for index, row in data.iterrows():
    # HTML formatting to increase font size
    popup_content = f"<div style='font-size: 21px;'>Name: {row['name']}<br>Postcode: {row['postcode']}</div>"
    
    folium.Marker(location=[row['latitude'], row['longitude']],
                  popup=popup_content,
                  icon=folium.Icon(color='green')).add_to(mymap)

# Save the map to an HTML file
mymap.save('postcode_map.html')

# Display the map
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
