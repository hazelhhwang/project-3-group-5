# %%
import geoplotlib
from geoplotlib.utils import read_csv, BoundingBox, DataAccessObject
import numpy
import csv
import pandas as pd

# %%
import folium
import pandas as pd

# Read the CSV file containing latitude, longitude, and postcode data
data = pd.read_csv('data_with_coordinates.csv')

# Create a map centered around the mean latitude and longitude coordinates
map_center = [data['latitude'].mean(), data['longitude'].mean()]
mymap = folium.Map(location=map_center, zoom_start=13)

# Add markers for each postcode location
for index, row in data.iterrows():
    folium.Marker(location=[row['latitude'], row['longitude']],
                  popup=row['postcode']).add_to(mymap)

# Save the map to an HTML file
mymap.save('postcode_map.html')

# Display the map
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb0ff5b49d1dfe3b774e91839ace51f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb0ff5b49d1dfe3b774e91839ace51f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb0ff5b49d1dfe3b774e91839ace51f4 = L.map(
#                 &quot;map_cb0ff5b49d1dfe3b774e91839ace51f4&quot;,
#                 {
#                     center: [-37.81937175757576, 144.97105086303029],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_97e8d2629c1db9d1be1fe37d9fa00aa2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_97e8d2629c1db9d1be1fe37d9fa00aa2.addTo(map_cb0ff5b49d1dfe3b774e91839ace51f4);
#
#
#             var marker_683d505037f93c1451b86cde2b222725 = L.marker(
#                 [-37.8116478, 144.9701118],
#                 {}
#             ).addTo(map_cb0ff5b49d1dfe3b774e91839ace51f4);
#
#
#         var popup_2fc7908d76fd91d59a3d1f661a413b61 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8c738a5c8b9ad8e428adfb6860a264f8 = $(`&lt;div id=&quot;html_8c738a5c8b9ad8e428adfb6860a264f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3000&lt;/div&gt;`)[0];
#                 popup_2fc7908d76fd91d59a3d1f661a413b61.setContent(html_8c738a5c8b9ad8e428adfb6860a264f8);
#
#
#
#         marker_683d505037f93c1451b86cde2b222725.bindPopup(popup_2fc7908d76fd91d59a3d1f661a413b61)
#         ;
#
#
#
#
#             var marker_3da575b4a59b408de0bceec4a38b1ef0 = L.marker(
#                 [-37.8132826, 144.9617644],
#                 {}
#             ).addTo(map_cb0ff5b49d1dfe3b774e91839ace51f4);
#
#
#         var popup_bfa01f5f2d1f5414c0551f5f004451eb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b9ed2f1fdb0d4e4ab103660121aa4b97 = $(`&lt;div id=&quot;html_b9ed2f1fdb0d4e4ab103660121aa4b97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3000&lt;/div&gt;`)[0];
#                 popup_bfa01f5f2d1f5414c0551f5f004451eb.setContent(html_b9ed2f1fdb0d4e4ab103660121aa4b97);
#
#
#
#         marker_3da575b4a59b408de0bceec4a38b1ef0.bindPopup(popup_bfa01f5f2d1f5414c0551f5f004451eb)
#         ;
#
#
#
#
#             var marker_9253e9a2f08be15c9266131089da46c6 = L.marker(
#                 [-37.8156004, 144.9629205],
#                 {}
#             ).addTo(map_cb0ff5b49d1dfe3b774e91839ace51f4);
#
#
#         var popup_89e148a4c02db44837f6738c69c7f373 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0ac339a90672946a9be2a004ac536d12 = $(`&lt;div id=&quot;html_0ac339a90672946a9be2a004ac536d12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3000&lt;/div&gt;`)[0];
#                 popup_89e148a4c02db44837f6738c69c7f373.setContent(html_0ac339a90672946a9be2a004ac536d12);
#
#
#
#         marker_9253e9a2f08be15c9266131089da46c6.bindPopup(popup_89e148a4c02db44837f6738c69c7f373)
#         ;
#
#
#
#
#             var marker_3e690a719bb470958150b0453aa3f5d7 = L.marker(
#                 [-37.8153266, 144.9661686],
#                 {}
#             ).addTo(map_cb0ff5b49d1dfe3b774e91839ace51f4);
#
#
#         var popup_59d3f18c143bfeccad869089f6708b9f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_130bb0bdc0d05ee04f3033807f75795d = $(`&lt;div id=&quot;html_130bb0bdc0d05ee04f3033807f75795d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3000&lt;/div&gt;`)[0];
#                 popup_59d3f18c143bfeccad869089f6708b9f.setContent(html_130bb0bdc0d05ee04f3033807f75795d);
#
#
#
#         marker_3e690a719bb470958150b0453aa3f5d7.bindPopup(popup_59d3f18c143bfeccad869089f6708b9f)
#         ;
#
#
#
#
#             var marker_6131efeff565aeb7256427c566db081d = L.marker(
#                 [-37.8075798, 144.956785],
#                 {}
#             ).addTo(map_cb0ff5b49d1dfe3b774e91839ace51f4);
#
#
#         var popup_ead66607d4243c24814c7ba38c1a6560 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3098e6889d7b301ce006aa08c1952eb5 = $(`&lt;div id=&quot;html_3098e6889d7b301ce006aa08c1952eb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3000&lt;/div&gt;`)[0];
#                 popup_ead66607d4243c24814c7ba38c1a6560.setContent(html_3098e6889d7b301ce006aa08c1952eb5);
#
#
#
#         marker_6131efeff565aeb7256427c566db081d.bindPopup(popup_ead66607d4243c24814c7ba38c1a6560)
#         ;
#
#
#
#
#             var marker_b909ae64ef7654f33a6abeb686c53dbd = L.marker(
#                 [-37.7759622, 144.9705236],
#                 {}
#             ).addTo(map_cb0ff5b49d1dfe3b774e91839ace51f4);

# %%
import folium
from folium.plugins import HeatMap
import pandas as pd

# Read the CSV file containing latitude, longitude, and postcode data
data = pd.read_csv('data_with_coordinates.csv')

# Create a map centered around the mean latitude and longitude coordinates
map_center = [data['latitude'].mean(), data['longitude'].mean()]
mymap = folium.Map(location=map_center, zoom_start=13)

# Convert latitude and longitude data to a list of points for heatmap
heat_data = data[['latitude', 'longitude']].values.tolist()

# Create a HeatMap layer
HeatMap(heat_data).add_to(mymap)

# Save the map to an HTML file
mymap.save('heatmap.html')

# Display the map
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_283efb46ae0e676a578795467fa3fedd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_283efb46ae0e676a578795467fa3fedd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_283efb46ae0e676a578795467fa3fedd = L.map(
#                 &quot;map_283efb46ae0e676a578795467fa3fedd&quot;,
#                 {
#                     center: [-37.81937175757576, 144.97105086303029],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_760071e46b7b0adb22334b40eab4e56c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_760071e46b7b0adb22334b40eab4e56c.addTo(map_283efb46ae0e676a578795467fa3fedd);
#
#
#             var heat_map_b435a5583f2df7484a9c818053ec8418 = L.heatLayer(
#                 [[-37.8116478, 144.9701118], [-37.8132826, 144.9617644], [-37.8156004, 144.9629205], [-37.8153266, 144.9661686], [-37.8075798, 144.956785], [-37.7759622, 144.9705236], [-37.8157961, 144.9713157], [-37.8129395, 144.9606336], [-37.8373679, 144.9428952], [-37.8686333, 144.9793638], [-37.797763, 144.971058], [-37.812125, 144.9729651], [-37.8167121, 144.9656432], [-37.8558896, 145.0246644], [-37.8126386, 144.9597071], [-37.8053936, 144.9495793], [-37.805959, 144.9811802], [-37.819114, 145.0026469], [-37.8406353, 144.9552576], [-37.8496092, 144.9922938], [-37.8188668, 144.9676883], [-37.8059444, 144.980922], [-37.8208482, 144.963894], [-37.81124, 144.966611], [-37.8139461, 144.9734456], [-37.8466651, 144.9493763], [-37.8770079, 144.9972755], [-37.8024898, 144.9494399], [-37.8123976, 145.0788504], [-37.8226854, 145.0343087], [-37.8342416, 144.9819669], [-37.8255231, 144.9975909], [-37.8109675, 144.9711221], [-37.8595121, 144.9786951], [-37.8114817, 144.9692505], [-37.8241955, 144.9513512], [-37.8128109, 144.9725205], [-37.8091066, 144.9617066], [-37.820556, 144.965833], [-37.8114087, 144.9708873], [-37.8179789, 144.9690576], [-37.8216356, 144.964539], [-37.8417615, 144.9361703], [-37.815191, 144.9418785], [-37.8159032, 144.9635352], [-37.8106632, 144.9702948], [-37.8326873, 144.9582451], [-37.8372567, 144.9791898], [-37.8238395, 144.9599367], [-37.9095792, 144.9865978], [-37.8479584, 145.0035058], [-37.815038, 144.967359], [-37.7980483, 144.9786674], [-37.8238758, 144.9676033], [-37.802065, 144.978038], [-37.8203389, 144.9660726], [-37.8104963, 144.9692505], [-37.9212107, 145.0579728], [-37.8521396, 144.9931653], [-37.8117326, 144.9710426], [-37.8195514, 145.0071773], [-37.8162209, 144.970288], [-37.8154437, 144.9678587], [-37.8114463, 144.9598499], [-37.915485, 144.996401], [-37.8135623, 144.9621017], [-37.7981479, 144.9677661], [-37.8164259, 144.9657009], [-37.8136276, 144.9630576], [-37.8135391, 144.9632758], [-37.8169409, 144.9658414], [-37.8014047, 144.9666468], [-37.812531, 144.973326], [-37.8167121, 144.9656432], [-37.8203662, 144.9559713], [-37.8361923, 144.9761994], [-37.8153106, 144.9642704], [-37.8401779, 144.9952728], [-37.8149147, 144.964256], [-37.8170652, 144.9419122], [-37.8045201, 144.9665773], [-37.7986042, 144.9685933], [-37.7658611, 144.9198186], [-37.8135337, 144.9597639], [-37.814926, 144.972489], [-37.8075681, 145.0387546], [-37.819944, 144.955791], [-37.8326392, 144.9582379], [-37.8397261, 144.9962375], [-37.7662302, 144.9217422], [-37.8156575, 144.9703881], [-37.8123889, 144.9667083], [-37.8677208, 144.9792653], [-37.8175103, 144.9675235], [-37.8123362, 144.9637384], [-37.8149489, 144.9640984], [-37.8402774, 144.9403195], [-37.8685613, 144.9800196], [-37.8109568, 144.9724344], [-37.813028, 144.9608737], [-37.8320111, 144.9559391], [-37.8699209, 144.9804934], [-37.825931, 144.998803], [-37.8157661, 144.9698897], [-37.774643, 144.962468], [-37.8152145, 144.9700836], [-37.8235301, 144.9580953], [-37.8121517, 144.9651729], [-37.814514, 144.961545], [-37.773417, 144.96087], [-37.8143958, 144.9644574], [-37.8382928, 144.9901259], [-37.8149132, 144.9731229], [-37.8164269, 144.9604517], [-37.7992964, 144.9674499], [-37.8155625, 144.9627123], [-37.8040315, 144.9666273], [-37.8385804, 144.9896578], [-37.8107359, 144.9714889], [-37.807859, 144.960611], [-37.819844, 144.9564659], [-37.815111, 144.9618289], [-37.8378891, 145.0844389], [-37.7989985, 144.96839], [-37.8247906, 144.9511172], [-37.8156004, 144.9629205], [-37.8107046, 144.9634756], [-37.7995258, 144.9674972], [-37.8685701, 144.9750806], [-37.8168643, 144.9661048], [-37.8119386, 144.9646576], [-37.7906587, 145.0959269], [-37.8157231, 144.9715309], [-37.8385826, 144.989712], [-37.8119053, 144.9702831], [-37.816633, 144.9655106], [-37.813423, 144.9686637], [-37.810779, 144.9685513], [-37.8061009, 144.9687226], [-37.7701508, 144.9262288], [-37.7732119, 144.9979146

# %%
import folium
import pandas as pd

# Read the CSV file containing latitude, longitude, and postcode data
data = pd.read_csv('data_with_coordinates.csv')

# Create a map centered around the mean latitude and longitude coordinates
map_center = [data['latitude'].mean(), data['longitude'].mean()]
mymap = folium.Map(location=map_center, zoom_start=15)

# Add markers for each postcode location
for index, row in data.iterrows():
    folium.Marker(location=[row['latitude'], row['longitude']],
                  popup=row['postcode'],
                  icon=folium.Icon(color='green')).add_to(mymap)  # Set marker color to purple

# Save the map to an HTML file
mymap.save('postcode_map.html')

# Display the map
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d8425ef0bfb70554faa1089eaf41836b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d8425ef0bfb70554faa1089eaf41836b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d8425ef0bfb70554faa1089eaf41836b = L.map(
#                 &quot;map_d8425ef0bfb70554faa1089eaf41836b&quot;,
#                 {
#                     center: [-37.81937175757576, 144.97105086303029],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_96362f0708d5e13d53ea92ed449795fc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_96362f0708d5e13d53ea92ed449795fc.addTo(map_d8425ef0bfb70554faa1089eaf41836b);
#
#
#             var marker_e89d2c8f61bfd07575e3d0eee79839d9 = L.marker(
#                 [-37.8116478, 144.9701118],
#                 {}
#             ).addTo(map_d8425ef0bfb70554faa1089eaf41836b);
#
#
#             var icon_e3e561fa67edc210b06d6f58ab13f80a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e89d2c8f61bfd07575e3d0eee79839d9.setIcon(icon_e3e561fa67edc210b06d6f58ab13f80a);
#
#
#         var popup_4e1a664594329ace8bb2ff5a7a0d4dcb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ed65cca67f91286817cf5eb9c41b9986 = $(`&lt;div id=&quot;html_ed65cca67f91286817cf5eb9c41b9986&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3000&lt;/div&gt;`)[0];
#                 popup_4e1a664594329ace8bb2ff5a7a0d4dcb.setContent(html_ed65cca67f91286817cf5eb9c41b9986);
#
#
#
#         marker_e89d2c8f61bfd07575e3d0eee79839d9.bindPopup(popup_4e1a664594329ace8bb2ff5a7a0d4dcb)
#         ;
#
#
#
#
#             var marker_f501c4b6340015f69d39ba4c3ff5c94d = L.marker(
#                 [-37.8132826, 144.9617644],
#                 {}
#             ).addTo(map_d8425ef0bfb70554faa1089eaf41836b);
#
#
#             var icon_9724de79963a61b5034e0f69547f51b5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f501c4b6340015f69d39ba4c3ff5c94d.setIcon(icon_9724de79963a61b5034e0f69547f51b5);
#
#
#         var popup_cdeec8a2a185437a010e5fe1aaec1315 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8fc0d6350b3e1f70d5916d5ba0fd0fe2 = $(`&lt;div id=&quot;html_8fc0d6350b3e1f70d5916d5ba0fd0fe2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3000&lt;/div&gt;`)[0];
#                 popup_cdeec8a2a185437a010e5fe1aaec1315.setContent(html_8fc0d6350b3e1f70d5916d5ba0fd0fe2);
#
#
#
#         marker_f501c4b6340015f69d39ba4c3ff5c94d.bindPopup(popup_cdeec8a2a185437a010e5fe1aaec1315)
#         ;
#
#
#
#
#             var marker_822e0699db6549f7ca72ba38eff549d8 = L.marker(
#                 [-37.8156004, 144.9629205],
#                 {}
#             ).addTo(map_d8425ef0bfb70554faa1089eaf41836b);
#
#
#             var icon_1f8b8b7dc99dbe7109d838b4f0f704c5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_822e0699db6549f7ca72ba38eff549d8.setIcon(icon_1f8b8b7dc99dbe7109d838b4f0f704c5);
#
#
#         var popup_96abe04b4102f8ebf60b3780923d0f98 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_30c34344b38cfe118d52b50f5c9b07ea = $(`&lt;div id=&quot;html_30c34344b38cfe118d52b50f5c9b07ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3000&lt;/div&gt;`)[0];
#                 popup_96abe04b4102f8ebf60b3780923d0f98.setContent(html_30c34344b38cfe118d52b50f5c9b07ea);
#
#
#
#         marker_822e0699db6549f7ca72ba38eff549d8.bindPopup(popup_96abe04b4102f8ebf60b3780923d0f98)
#         ;
#
#
#
#
#             var marker_a8498690d357150b70748d355237004f = L.marker(
#                 [-37.8153266, 144.9661686],
#                 {}
#             ).addTo(map_d8425ef0bfb70554faa1089eaf41836b);
#
#
#             var icon_a670473b90552fa629bdf55ff4bb5ccf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &
